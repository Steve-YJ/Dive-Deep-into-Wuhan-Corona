# %% [markdown]
# # Kaggle Tutorial
# * Corona Virus Visualization

# %% [markdown]
# This notebook tracks the spread of the novel corona viurs known as the 2019-nCoV.<br/>
# It is a contagious respiratory virus that first started in Wuhan in December 2019.

# %%
# import library

import numpy as np
import matplotlib.pyplot as plt  # 시각화를 위한 패키지
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('2019_nCoV_20200121_20200129.csv')  # 2020년 01.21부터 01.29까지의 데이터
data.head()
# Out:
#   Province/State  Country/Region      Last Update  Confirmed  Suspected  \
# 0          Hubei  Mainland China  1/29/2020 21:00     4586.0        NaN
# 1       Zhejiang  Mainland China  1/29/2020 21:00      428.0        NaN
# 2      Guangdong  Mainland China  1/29/2020 21:00      311.0        NaN
# 3          Henan  Mainland China  1/29/2020 21:00      278.0        NaN
# 4          Hunan  Mainland China  1/29/2020 21:00      277.0        NaN
#
#    Recovered  Death
# 0       90.0  162.0
# 1        4.0    NaN
# 2        6.0    NaN
# 3        2.0    2.0
# 4        NaN    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 7 columns):
# Province/State    713 non-null object
# Country/Region    883 non-null object
# Last Update       883 non-null object
# Confirmed         853 non-null float64
# Suspected         88 non-null float64
# Recovered         154 non-null float64
# Death             94 non-null float64
# dtypes: float64(4), object(3)
# memory usage: 48.4+ KB

# %% [markdown]
# * Province/State : 지방 또는 주
# * Country/Region : 국가
# * Last Update    : 최신 업데이트 로그
# * Confirmed      : 확진자 수
# * Suspected      : 의심환자 수
# * Recovered      : Recovered?
# * Death          : 사망자 수

# %% [markdown]
# * Looking at Date last updated, a categorical variable

# %%
type(data['Last Update'].unique())
# Out:
# numpy.ndarray

# %%
unique_dates = data['Last Update'].unique().tolist()
unique_dates.sort()
unique_dates
# Out:
# ['1/21/2020',
#  '1/22/2020 12:00',
#  '1/23/20 12:00 PM',
#  '1/24/2020 12:00 AM',
#  '1/24/2020 12:00 PM',
#  '1/24/2020 4:00 PM',
#  '1/25/2020 10:00 PM',
#  '1/25/2020 12:00 AM',
#  '1/25/2020 12:00 PM',
#  '1/26/2020 11:00 AM',
#  '1/26/2020 23:00',
#  '1/27/2020 19:00',
#  '1/27/2020 20:30',
#  '1/27/2020 9:00',
#  '1/28/2020 13:00',
#  '1/28/2020 18:00',
#  '1/28/2020 23:00',
#  '1/29/2020 13:30',
#  '1/29/2020 14:30',
#  '1/29/2020 21:00']

# %%
# 1월 21일 부터 1월 29일 21시까지 업데이트가 되었다

# %%
data['Last Update'] == '1/21/2020'  # boolean index?
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 878     True
# 879     True
# 880     True
# 881     True
# 882     True
# Name: Last Update, Length: 883, dtype: bool

# %%
OOOOOOOOOUUOEEOOOOO

# %%
world_cases = []  # world case

for i in unique_dates:
    world_cases.append(data[data['Last Update'] == i].Confirmed.sum())







world_cases = []

for i in unique_dates:
    world_cases.append(data[data['Last Update'] == i].Confirmed.sum())
    
print(unique_dates, world_cases)

# %% [markdown]
# * Remove redundant time

# %%
excess_time = [ '1/24/2020 4:00 PM', '1/26/2020 11:00 AM',  '1/27/2020 9:00']
for i in excess_time:
    unique_dates.remove(i)

# %%
# Q. 불필요한 날짜의 기준은 어떻게 될까?

# %%
plt.figure(figsize=(20, 12))
plt.plot(unique_dates, world_cases)
plt.title('# of Coronavirus Cases Over Time', size = 30)
plt.xlabel('Time', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(rotation=90, size=15)
plt.show()

# %% [markdown]
# * 모든 시간대에서 그림을 그려보니 1/24/2020 4:00 PM, 1/26/2020 11:00 AM, 1/27/2020 9:00에서 누적이 오히려 감소하는 것을 볼 수 있다.
# * 위의 3가지 시간대를 제거해준다.

# %%
world_cases = []

for i in unique_dates:
    world_cases.append(data[data['Last Update'] == i].Confirmed.sum())
    
print(unique_dates, world_cases)
# Out:
# ['1/21/2020', '1/22/2020 12:00', '1/23/20 12:00 PM', '1/24/2020 12:00 AM', '1/24/2020 12:00 PM', '1/25/2020 10:00 PM', '1/25/2020 12:00 AM', '1/25/2020 12:00 PM', '1/26/2020 23:00', '1/27/2020 19:00', '1/27/2020 20:30', '1/28/2020 13:00', '1/28/2020 18:00', '1/28/2020 23:00', '1/29/2020 13:30', '1/29/2020 14:30', '1/29/2020 21:00'] [332.0, 555.0, 653.0, 881.0, 939.0, 1156.0, 1354.0, 2301.0, 2794.0, 2927.0, 4473.0, 4690.0, 5579.0, 6056.0, 6164.0, 6165.0, 7783.0]

# %% [markdown]
# * 일별로 확진자수는 어떻게 변할까?
#     * 일별 최종 업데이트를 기준으로(하루의 끝 자락에서) 그래프를 그려보자

# %% [markdown]
# * Gargraph the confirmed cases

# %%
world_cases = []

for i in unique_dates:
    world_cases.append(data[data['Last Update']==i].Confirmed.sum())
    
print(unique_dates, world_cases)
# Out:
# ['1/21/2020', '1/22/2020 12:00', '1/23/20 12:00 PM', '1/24/2020 12:00 AM', '1/24/2020 12:00 PM', '1/25/2020 10:00 PM', '1/25/2020 12:00 AM', '1/25/2020 12:00 PM', '1/26/2020 23:00', '1/27/2020 19:00', '1/27/2020 20:30', '1/28/2020 13:00', '1/28/2020 18:00', '1/28/2020 23:00', '1/29/2020 13:30', '1/29/2020 14:30', '1/29/2020 21:00'] [332.0, 555.0, 653.0, 881.0, 939.0, 1156.0, 1354.0, 2301.0, 2794.0, 2927.0, 4473.0, 4690.0, 5579.0, 6056.0, 6164.0, 6165.0, 7783.0]

# %%
plt.figure(figsize=(20, 12))
plt.plot(unique_dates, world_cases)
plt.title('# of Coronavirus Cases Over Time', size = 30)
plt.xlabel('Time', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(rotation=50, size=15)
plt.show()

# %% [markdown]
# * 확진자수 뿐만아니라 사망자수도 그래프로 시각화 할 수 있다.

# %% [markdown]
# looking ad the latest confirmed data

# %%
latest_date = '1/29/2020 21:00'
data[data['Last Update']==latest_date]
# Out:
#       Province/State        Country/Region      Last Update  Confirmed  \
# 0              Hubei        Mainland China  1/29/2020 21:00     4586.0
# 1           Zhejiang        Mainland China  1/29/2020 21:00      428.0
# 2          Guangdong        Mainland China  1/29/2020 21:00      311.0
# 3              Henan        Mainland China  1/29/2020 21:00      278.0
# 4              Hunan        Mainland China  1/29/2020 21:00      277.0
# 5              Anhui        Mainland China  1/29/2020 21:00      200.0
# 6          Chongqing        Mainland China  1/29/2020 21:00      165.0
# 7            Jiangxi        Mainland China  1/29/2020 21:00      162.0
# 8           Shandong        Mainland China  1/29/2020 21:00      145.0
# 9            Sichuan        Mainland China  1/29/2020 21:00      142.0
# 10           Jiangsu        Mainland China  1/29/2020 21:00      129.0
# 11           Beijing        Mainland China  1/29/2020 21:00      111.0
# 12          Shanghai        Mainland China  1/29/2020 21:00      101.0
# 13            Fujian        Mainland China  1/29/2020 21:00      101.0
# 14           Guangxi        Mainland China  1/29/2020 21:00       78.0
# 15             Hebei        Mainland China  1/29/2020 21:00       65.0
# 16           Shaanxi        Mainland China  1/29/2020 21:00       56.0
# 17            Yunnan        Mainland China  1/29/2020 21:00       55.0
# 18            Hainan        Mainland China  1/29/2020 21:00       43.0
# 19      Heilongjiang        Mainland China  1/29/2020 21:00       43.0
# 20          Liaoning        Mainland China  1/29/2020 21:00       39.0
# 21            Shanxi        Mainland China  1/29/2020 21:00       35.0
# 22           Tianjin        Mainland China  1/29/2020 21:00       27.0
# 23             Gansu        Mainland China  1/29/2020 21:00       26.0
# 24    Inner Mongolia        Mainland China  1/29/2020 21:00       16.0
# 25             Jilin        Mainland China  1/29/2020 21:00       14.0
# 26          Xinjiang        Mainland China  1/29/2020 21:00       14.0
# 27           Guizhou        Mainland China  1/29/2020 21:00       12.0
# 28           Ningxia        Mainland China  1/29/2020 21:00       12.0
# 29         Hong Kong             Hong Kong  1/29/2020 21:00       10.0
# 30            Taiwan                Taiwan  1/29/2020 21:00        8.0
# 31             Macau                 Macau  1/29/2020 21:00        7.0
# 32           Qinghai        Mainland China  1/29/2020 21:00        6.0
# 33             Tibet        Mainland China  1/29/2020 21:00        1.0
# 34        Washington         United States  1/29/2020 21:00        1.0
# 35          Illinois         United States  1/29/2020 21:00        1.0
# 36        California         United States  1/29/2020 21:00        2.0
# 37           Arizona         United States  1/29/2020 21:00        1.0
# 38               NaN                 Japan  1/29/2020 21:00       11.0
# 39               NaN              Thailand  1/29/2020 21:00       14.0
# 40               NaN           South Korea  1/29/2020 21:00        4.0
# 41               NaN             Singapore  1/29/2020 21:00       10.0
# 42               NaN               Vietnam  1/29/2020 21:00        2.0
# 43               NaN                France  1/29/2020 21:00        5.0
# 44               NaN                 Nepal  1/29/2020 21:00        1.0
# 45               NaN              Malaysia  1/29/2020 21:00        7.0
# 46           Ontario                Canada  1/29/2020 21:00        2.0
# 47  British Columbia                Canada  1/29/2020 21:00        1.0
# 48               NaN              Cambodia  1/29/2020 21:00        1.0
# 49               NaN             Sri Lanka  1/29/2020 21:00        1.0
# 50   New South Wales             Australia  1/29/2020 21:00        4.0
# 51          Victoria             Australia  1/29/2020 21:00        2.0
# 52        Queensland             Australia  1/29/2020 21:00        1.0
# 53           Bavaria               Germany  1/29/2020 21:00        4.0
# 54               NaN               Finland  1/29/2020 21:00        1.0
# 55               NaN  United Arab Emirates  1/29/2020 21:00        4.0
#
#     Suspected  Recovered  Death
# 0         NaN       90.0  162.0
# 1         NaN        4.0    NaN
# 2         NaN        6.0    NaN
# 3         NaN        2.0    2.0
# 4         NaN        NaN    NaN
# 5         NaN        2.0    NaN
# 6         NaN        1.0    NaN
# 7         NaN        4.0    NaN
# 8         NaN        1.0    NaN
# 9         NaN        1.0    1.0
# 10        NaN        1.0    NaN
# 11        NaN        4.0    1.0
# 12        NaN        5.0    1.0
# 13        NaN        NaN    NaN
# 14        NaN        2.0    NaN
# 15        NaN        NaN    1.0
# 16        NaN        NaN    NaN
# 17        NaN        NaN    NaN
# 18        NaN        NaN    1.0
# 19        NaN        NaN    1.0
# 20        NaN        1.0    NaN
# 21        NaN        1.0    NaN
# 22        NaN        NaN    NaN
# 23        NaN        NaN    NaN
# 24        NaN        NaN    NaN
# 25        NaN        1.0    NaN
# 26        NaN        NaN    NaN
# 27        NaN        1.0    NaN
# 28        NaN        NaN    NaN
# 29        NaN        NaN    NaN
# 30        NaN        NaN    NaN
# 31        NaN        NaN    NaN
# 32        NaN        NaN    NaN
# 33        NaN        NaN    NaN
# 34        NaN        NaN    NaN
# 35        NaN        NaN    NaN
# 36        NaN        NaN    NaN
# 37        NaN        NaN    NaN
# 38        NaN        1.0    NaN
# 39        NaN        5.0    NaN
# 40        NaN        NaN    NaN
# 41        NaN        NaN    NaN
# 42        NaN        NaN    NaN
# 43        NaN        NaN    NaN
# 44        NaN        NaN    NaN
# 45        NaN        NaN    NaN
# 46        NaN        NaN    NaN
# 47        NaN        NaN    NaN
# 48        NaN        NaN    NaN
# 49        NaN        NaN    NaN
# 50        NaN        NaN    NaN
# 51        NaN        NaN    NaN
# 52        NaN        NaN    NaN
# 53        NaN        NaN    NaN
# 54        NaN        NaN    NaN
# 55        NaN        NaN    NaN

# %% [markdown]
# Find countries/territories that have confirmed cases

# %%
# number of cases per province/state/city

unique_countries = data[data.Confirmed > 0]['Country/Region'].unique()
unique_countries.sort()
unique_countries
# Out:
# array(['Australia', 'Cambodia', 'Canada', 'Finland', 'France', 'Germany',
#        'Hong Kong', 'Ivory Coast', 'Japan', 'Macau', 'Mainland China',
#        'Malaysia', 'Nepal', 'Singapore', 'South Korea', 'Sri Lanka',
#        'Taiwan', 'Thailand', 'United Arab Emirates', 'United States',
#        'Vietnam'], dtype=object)

# %%
data['Last Update'] == '1/27/2020 9:00'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# Name: Last Update, Length: 883, dtype: bool

# %%
# 아래의 query가 의미하는 건 뭘까?

data[data['Last Update'] == '1/27/2020 9:00']

# Q. boolean Index?!
# Out:
#      Province/State  Country/Region     Last Update  Confirmed  Suspected  \
# 420           Hubei  Mainland China  1/27/2020 9:00     1423.0        NaN
# 421       Guangdong  Mainland China  1/27/2020 9:00      151.0        NaN
# 422        Zhejiang  Mainland China  1/27/2020 9:00      128.0        NaN
# 423           Henan  Mainland China  1/27/2020 9:00      128.0        NaN
# 424       Chongqing  Mainland China  1/27/2020 9:00      110.0        NaN
# 425           Hunan  Mainland China  1/27/2020 9:00      100.0        NaN
# 426        Shandong  Mainland China  1/27/2020 9:00       75.0        NaN
# 427         Beijing  Mainland China  1/27/2020 9:00       72.0        NaN
# 428           Anhui  Mainland China  1/27/2020 9:00       70.0        NaN
# 429         Sichuan  Mainland China  1/27/2020 9:00       69.0        NaN
# 430          Fujian  Mainland China  1/27/2020 9:00       56.0        NaN
# 431        Shanghai  Mainland China  1/27/2020 9:00       53.0        NaN
# 432         Jiangxi  Mainland China  1/27/2020 9:00       48.0        NaN
# 433         Jiangsu  Mainland China  1/27/2020 9:00       47.0        NaN
# 434         Guangxi  Mainland China  1/27/2020 9:00       46.0        NaN
# 435         Shaanxi  Mainland China  1/27/2020 9:00       35.0        NaN
# 436          Hainan  Mainland China  1/27/2020 9:00       33.0        NaN
# 437        Liaoning  Mainland China  1/27/2020 9:00       27.0        NaN
# 438          Yunnan  Mainland China  1/27/2020 9:00       26.0        NaN
# 439         Tianjin  Mainland China  1/27/2020 9:00       22.0        NaN
# 440    Heilongjiang  Mainland China  1/27/2020 9:00       21.0        NaN
# 441           Hebei  Mainland China  1/27/2020 9:00       18.0        NaN
# 442           Gansu  Mainland China  1/27/2020 9:00       14.0        NaN
# 443          Shanxi  Mainland China  1/27/2020 9:00       13.0        NaN
# 444  Inner Mongolia  Mainland China  1/27/2020 9:00       11.0        NaN
# 445       Hong Kong       Hong Kong  1/27/2020 9:00        8.0        NaN
# 446         Guizhou  Mainland China  1/27/2020 9:00        7.0        NaN
# 447         Ningxia  Mainland China  1/27/2020 9:00        7.0        NaN
# 448           Jilin  Mainland China  1/27/2020 9:00        6.0        NaN
# 449           Macau           Macau  1/27/2020 9:00        6.0        NaN
# 450          Taiwan          Taiwan  1/27/2020 9:00        5.0        NaN
# 451        Xinjiang  Mainland China  1/27/2020 9:00        5.0        NaN
# 452         Qinghai  Mainland China  1/27/2020 9:00        4.0        NaN
# 453      Washington   United States  1/27/2020 9:00        1.0        NaN
# 454        Illinois   United States  1/27/2020 9:00        1.0        NaN
# 455      California   United States  1/27/2020 9:00        2.0        NaN
# 456         Arizona   United States  1/27/2020 9:00        1.0        NaN
# 457             NaN           Japan  1/27/2020 9:00        4.0        NaN
# 458             NaN        Thailand  1/27/2020 9:00        8.0        NaN
# 459             NaN     South Korea  1/27/2020 9:00        4.0        NaN
# 460             NaN       Singapore  1/27/2020 9:00        4.0        NaN
# 461             NaN         Vietnam  1/27/2020 9:00        2.0        NaN
# 462             NaN          France  1/27/2020 9:00        3.0        NaN
# 463             NaN       Australia  1/27/2020 9:00        5.0        NaN
# 464             NaN           Nepal  1/27/2020 9:00        1.0        NaN
# 465             NaN        Malaysia  1/27/2020 9:00        4.0        NaN
# 466         Ontario          Canada  1/27/2020 9:00        1.0        NaN
# 467             NaN        Cambodia  1/27/2020 9:00        1.0        NaN
#
#      Recovered  Death
# 420       45.0   76.0
# 421        3.0    NaN
# 422        1.0    NaN
# 423        NaN    NaN
# 424        NaN    1.0
# 425        NaN    NaN
# 426        NaN    NaN
# 427        2.0    NaN
# 428        NaN    NaN
# 429        NaN    NaN
# 430        NaN    NaN
# 431        3.0    1.0
# 432        1.0    NaN
# 433        1.0    NaN
# 434        NaN    NaN
# 435        NaN    NaN
# 436        NaN    1.0
# 437        NaN    NaN
# 438        NaN    NaN
# 439        NaN    NaN
# 440        NaN    1.0
# 441        NaN    1.0
# 442        NaN    NaN
# 443        NaN    NaN
# 444        NaN    NaN
# 445        NaN    NaN
# 446        NaN    NaN
# 447        NaN    NaN
# 448        NaN    NaN
# 449        NaN    NaN
# 450        NaN    NaN
# 451        NaN    NaN
# 452        NaN    NaN
# 453        NaN    NaN
# 454        NaN    NaN
# 455        NaN    NaN
# 456        NaN    NaN
# 457        1.0    NaN
# 458        2.0    NaN
# 459        NaN    NaN
# 460        NaN    NaN
# 461        NaN    NaN
# 462        NaN    NaN
# 463        NaN    NaN
# 464        NaN    NaN
# 465        NaN    NaN
# 466        NaN    NaN
# 467        NaN    NaN
